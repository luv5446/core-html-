# %% [markdown]
# 1.  Build a simple webpage that displays text as shown in the below image.
#
# Ans:
# <DOCTYPE! html>
# <html>
# <title>
# html core assignment
# </title>
# <body>
#
# <b> this text will be bold </b>
#
# <i> this text will be italic </i>
#
# <u> this text is will be underlined </u>
#
# <mark>  this text will be highlighted </mark>
#
# this is normal text <sup> this is super scripted text </sup> this is normal text
#
#
# this is normal text <sub> this is sub scripted text </sub> this is normal text
#
# normal text <small> small text </small>
#
#
#
#
# </body>
# </html>
#
# 2.  Build a simple webpage that helps users navigate different web development-related websites. Note: On
# clicking the hyperlink the web pages should open in a new tab. Below is a reference image.
#
# Ans:
# <DOCTYPE! html>
# <html>
# <title>
# simple Webpage
# </title>
# <body>
#
# <h4><b> Navigate Me: </b> </h4>
#
# <p> Take me to <a href="https://pwskills.com/learn/"> PWskills</a> to buy a course <p>
#
# <p>take me to <a href="https://developer.mozilla.org/en-US/"> MDN Docs</a> to know more about web development </p>
# <p>Take me to <a href="https://pwskills.com/ ">PWs skill lab</a> To practise live coding </p>
#
#
#
#
# </body>
# </html>
#
#
# 3. Build a simple blog web page with 3 pages home, web development, and web design. Each page must
# contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information.
# For the home page you can add some information about yourself.
#
#
# Ans- <!DOCTYPE html>
# <html>
# <head>
#     <title>My Blog - Home</title>
# </head>
# <body>
#     <nav>
#         <a href="index.html">Home</a> |
#         <a href="web-development.html">Web Development</a> |
#         <a href="web-design.html">Web Design</a>
#     </nav>
#     <h1>Welcome to My Blog</h1>
#     <p>Hello! I'm a web enthusiast who enjoys building and designing websites. On this blog, I share my thoughts and tips on web development and design. Thanks for visiting!</p>
# </body>
# </html>
#
# <!DOCTYPE html>
# <html>
# <head>
#     <title>My Blog - Web Development</title>
# </head>
# <body>
#     <nav>
#         <a href="index.html">Home</a> |
#         <a href="web-development.html">Web Development</a> |
#         <a href="web-design.html">Web Design</a>
#     </nav>
#     <h1>Web Development</h1>
#     <p>Web development involves creating websites and web applications using technologies like HTML, CSS, JavaScript, and backend programming languages. It focuses on functionality and performance.</p>
# </body>
# </html>
#
# <!DOCTYPE html>
# <html>
# <head>
#     <title>My Blog - Web Design</title>
# </head>
# <body>
#     <nav>
#         <a href="index.html">Home</a> |
#         <a href="web-development.html">Web Development</a> |
#         <a href="web-design.html">Web Design</a>
#     </nav>
#     <h1>Web Design</h1>
#     <p>Web design is about creating visually appealing and user-friendly interfaces. It includes layout design, color theory, typography, and ensuring good user experience across all devices.</p>
# </body>
# </html>
#
#
# 4. Create an ordered list of HTML tags. Each list item must include the tag name and some information about
# the tag.
#
# Ans -  <!DOCTYPE html>
# <html>
# <head>
#     <title>Ordered List of HTML Tags</title>
# </head>
# <body>
#     <h1>Ordered List of HTML Tags</h1>
#     <ol>
#         <li><strong>&lt;html&gt;</strong> – The root element that wraps the entire HTML document.</li>
#         <li><strong>&lt;head&gt;</strong> – Contains metadata, links to stylesheets, and scripts.</li>
#         <li><strong>&lt;title&gt;</strong> – Sets the title of the webpage shown in the browser tab.</li>
#         <li><strong>&lt;body&gt;</strong> – Contains all the content that appears on the webpage.</li>
#         <li><strong>&lt;h1&gt; to &lt;h6&gt;</strong> – Define headings, from the largest (&lt;h1&gt;) to the smallest (&lt;h6&gt;).</li>
#         <li><strong>&lt;p&gt;</strong> – Represents a paragraph of text.</li>
#         <li><strong>&lt;a&gt;</strong> – Creates a hyperlink to another page or resource.</li>
#         <li><strong>&lt;img&gt;</strong> – Embeds an image in the document.</li>
#         <li><strong>&lt;ul&gt;</strong> – Defines an unordered (bulleted) list.</li>
#         <li><strong>&lt;ol&gt;</strong> – Defines an ordered (numbered) list.</li>
#         <li><strong>&lt;li&gt;</strong> – Represents a list item inside &lt;ul&gt; or &lt;ol&gt;.</li>
#         <li><strong>&lt;div&gt;</strong> – A block-level container used for grouping and layout.</li>
#         <li><strong>&lt;span&gt;</strong> – An inline container used to style a part of text.</li>
#         <li><strong>&lt;br&gt;</strong> – Inserts a line break in the text.</li>
#         <li><strong>&lt;form&gt;</strong> – Defines a form for collecting user input.</li>
#     </ol>
# </body>
# </html>
#
#
# 5. Create a description list of full stack web development tech stack, using the <dl> tag. Each term should be
# a tech stack name and each description should be a brief explanation of what the tech stack is used for?
#
# Ans - <!DOCTYPE html>
# <html>
# <head>
#     <title>Ordered List of HTML Tags</title>
# </head>
# <body>
#     <h1>Ordered List of HTML Tags</h1>
#     <ol>
#         <li><strong>&lt;html&gt;</strong> – The root element that wraps the entire HTML document.</li>
#         <li><strong>&lt;head&gt;</strong> – Contains metadata, links to stylesheets, and scripts.</li>
#         <li><strong>&lt;title&gt;</strong> – Sets the title of the webpage shown in the browser tab.</li>
#         <li><strong>&lt;body&gt;</strong> – Contains all the content that appears on the webpage.</li>
#         <li><strong>&lt;h1&gt; to &lt;h6&gt;</strong> – Define headings, from the largest (&lt;h1&gt;) to the smallest (&lt;h6&gt;).</li>
#         <li><strong>&lt;p&gt;</strong> – Represents a paragraph of text.</li>
#         <li><strong>&lt;a&gt;</strong> – Creates a hyperlink to another page or resource.</li>
#         <li><strong>&lt;img&gt;</strong> – Embeds an image in the document.</li>
#         <li><strong>&lt;ul&gt;</strong> – Defines an unordered (bulleted) list.</li>
#         <li><strong>&lt;ol&gt;</strong> – Defines an ordered (numbered) list.</li>
#         <li><strong>&lt;li&gt;</strong> – Represents a list item inside &lt;ul&gt; or &lt;ol&gt;.</li>
#         <li><strong>&lt;div&gt;</strong> – A block-level container used for grouping and layout.</li>
#         <li><strong>&lt;span&gt;</strong> – An inline container used to style a part of text.</li>
#         <li><strong>&lt;br&gt;</strong> – Inserts a line break in the text.</li>
#         <li><strong>&lt;form&gt;</strong> – Defines a form for collecting user input.</li>
#     </ol>
# </body>
# </html>
# 6. Create an ordered list of the full stack web development tech stack HTML, CSS, and JS. For each tech
# stack, create a table that lists the tech stack name, its primary use cases, and some key features or
# benefits. Below is a reference image.
#
# Ans -
#
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Full Stack Web Development Tech Stack</title>
#     <style>
#         table {
#             width: 70%;
#             border-collapse: collapse;
#             margin-bottom: 20px;
#         }
#         th, td {
#             border: 1px solid #444;
#             padding: 8px;
#             text-align: left;
#         }
#         th {
#             background-color: #ddd;
#         }
#     </style>
# </head>
# <body>
#     <h1>Full Stack Web Development Tech Stack</h1>
#     <ol>
#         <li>
#             <h2>HTML</h2>
#             <table>
#                 <tr>
#                     <th>Tech Stack Name</th>
#                     <th>Primary Use Cases</th>
#                     <th>Key Features / Benefits</th>
#                 </tr>
#                 <tr>
#                     <td>HTML</td>
#                     <td>Structuring web content and layout</td>
#                     <td>
#                         - Semantic elements<br>
#                         - Easy to learn<br>
#                         - Foundation of all web pages
#                     </td>
#                 </tr>
#             </table>
#         </li>
#         <li>
#             <h2>CSS</h2>
#             <table>
#                 <tr>
#                     <th>Tech Stack Name</th>
#                     <th>Primary Use Cases</th>
#                     <th>Key Features / Benefits</th>
#                 </tr>
#                 <tr>
#                     <td>CSS</td>
#                     <td>Styling HTML elements, layouts, and visual design</td>
#                     <td>
#                         - Supports responsive design<br>
#                         - Separation of content and style<br>
#                         - Flexbox and Grid for layouts
#                     </td>
#                 </tr>
#             </table>
#         </li>
#         <li>
#             <h2>JavaScript</h2>
#             <table>
#                 <tr>
#                     <th>Tech Stack Name</th>
#                     <th>Primary Use Cases</th>
#                     <th>Key Features / Benefits</th>
#                 </tr>
#                 <tr>
#                     <td>JavaScript</td>
#                     <td>Creating interactive and dynamic content</td>
#                     <td>
#                         - Runs in the browser<br>
#                         - Event-driven and asynchronous<br>
#                         - Large ecosystem and libraries
#                     </td>
#                 </tr>
#             </table>
#         </li>
#     </ol>
# </body>
# </html>
#
# 7. 7 Build a complex nested list structure representing a multi-level table of contents. Use unordered lists
# (<ul>) and list items (<li>) with inline-block styling to create a structured layout. Apply formatting tags to
# enhance the presentation of list items.
#
# Ans -
#
#  <!DOCTYPE html>
# <html>
# <head>
#     <title>Multi-Level Table of Contents</title>
# </head>
# <body>
#     <h1>📘 Table of Contents</h1>
#
#     <ul>
#         <li><strong>1. Introduction</strong>
#             <ul>
#                 <li><em>1.1 About This Guide</em></li>
#                 <li><em>1.2 Who Should Read This?</em></li>
#             </ul>
#         </li>
#
#         <li><strong>2. Getting Started</strong>
#             <ul>
#                 <li><em>2.1 Installation</em>
#                     <ul>
#                         <li>2.1.1 System Requirements</li>
#                         <li>2.1.2 Setup Process</li>
#                     </ul>
#                 </li>
#                 <li><em>2.2 First Project</em></li>
#             </ul>
#         </li>
#
#         <li><strong>3. Core Concepts</strong>
#             <ul>
#                 <li><em>3.1 HTML Basics</em></li>
#                 <li><em>3.2 CSS Fundamentals</em>
#                     <ul>
#                         <li>3.2.1 Selectors</li>
#                         <li>3.2.2 Box Model</li>
#                         <li>3.2.3 Flexbox</li>
#                     </ul>
#                 </li>
#                 <li><em>3.3 JavaScript Essentials</em></li>
#             </ul>
#         </li>
#
#         <li><strong>4. Advanced Topics</strong>
#             <ul>
#                 <li><em>4.1 APIs and Fetch</em></li>
#                 <li><em>4.2 Deployment</em></li>
#             </ul>
#         </li>
#
#         <li><strong>5. Appendices</strong>
#             <ul>
#                 <li><em>5.1 Glossary</em></li>
#                 <li><em>5.2 Resources</em></li>
#             </ul>
#         </li>
#     </ul>
#
# </body>
# </html>
